# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read_DataSet

# %%
data = pd.read_csv(r"D:\JUPYTER_WORK\$um!T\4.Machine_learning\5.Loan_prediction_mam_assignement\loan_approval_data.csv")
df = pd.DataFrame(data)
df.sample(5)
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 623         624.0           14234.0              3249.0          Salaried
# 718         719.0           19844.0              4431.0          Salaried
# 981         982.0            5452.0              9956.0     Self-employed
# 911         912.0           14312.0              7373.0        Unemployed
# 502         503.0           14972.0              3665.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 623  22.0         Single         0.0           NaN             4.0       0.52
# 718  42.0         Single         1.0         729.0             0.0       0.24
# 981  37.0         Single         2.0         784.0             3.0       0.37
# 911  49.0            NaN         1.0         631.0             3.0       0.45
# 502  39.0         Single         2.0         745.0             0.0       0.25
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 623  14166.0            5239.0       1015.0       48.0     Business
# 718    660.0            6877.0      30989.0       48.0    Education
# 981  16651.0            4666.0      15662.0       48.0    Education
# 911  11322.0            2365.0      32668.0       60.0     Personal
# 502   1892.0           23402.0      18412.0       84.0         Home
#
#     Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 623           NaN    Not Graduate  Female        Unemployed            No
# 718     Semiurban    Not Graduate  Female          Business           Yes
# 981         Urban        Graduate    Male        Unemployed           Yes
# 911     Semiurban        Graduate    Male        Government            No
# 502         Urban        Graduate  Female          Business           Yes

# %%
df.describe()
# Out:
#        Applicant_ID  Applicant_Income  Coapplicant_Income         Age  \
# count    950.000000        950.000000          950.000000  950.000000
# mean     501.220000      10852.571579         5082.455789   39.971579
# std      289.608451       5061.632859         2943.161570   11.139797
# min        1.000000       2009.000000            1.000000   21.000000
# 25%      250.250000       6730.750000         2472.750000   30.250000
# 50%      499.500000      10548.000000         5205.500000   40.000000
# 75%      752.750000      15190.000000         7620.750000   49.000000
# max     1000.000000      19988.000000         9996.000000   59.000000
#
#        Dependents  Credit_Score  Existing_Loans   DTI_Ratio       Savings  \
# count  950.000000    950.000000      950.000000  950.000000    950.000000
# mean     1.474737    676.033684        1.950526    0.347263   9940.452632
# std      1.105067     71.346015        1.406246    0.144341   5860.736885
# min      0.000000    550.000000        0.000000    0.100000     65.000000
# 25%      1.000000    616.250000        1.000000    0.220000   4760.250000
# 50%      1.000000    678.000000        2.000000    0.340000   9880.500000
# 75%      2.000000    737.000000        3.000000    0.480000  15074.500000
# max      3.000000    799.000000        4.000000    0.600000  19996.000000
#
#        Collateral_Value   Loan_Amount   Loan_Term
# count        950.000000    950.000000  950.000000
# mean       24802.792632  20522.825263   48.000000
# std        14345.696031  11504.142575   24.245322
# min           36.000000   1015.000000   12.000000
# 25%        12698.250000   9806.250000   24.000000
# 50%        24321.000000  21210.500000   48.000000
# 75%        36947.000000  30263.000000   72.000000
# max        49954.000000  39995.000000   84.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        950 non-null    float64
#  1   Applicant_Income    950 non-null    float64
#  2   Coapplicant_Income  950 non-null    float64
#  3   Employment_Status   950 non-null    object
#  4   Age                 950 non-null    float64
#  5   Marital_Status      950 non-null    object
#  6   Dependents          950 non-null    float64
#  7   Credit_Score        950 non-null    float64
#  8   Existing_Loans      950 non-null    float64
#  9   DTI_Ratio           950 non-null    float64
#  10  Savings             950 non-null    float64
#  11  Collateral_Value    950 non-null    float64
#  12  Loan_Amount         950 non-null    float64
#  13  Loan_Term           950 non-null    float64
#  14  Loan_Purpose        950 non-null    object
#  15  Property_Area       950 non-null    object
#  16  Education_Level     950 non-null    object
#  17  Gender              950 non-null    object
#  18  Employer_Category   950 non-null    object
#  19  Loan_Approved       950 non-null    object
# dtypes: float64(12), object(8)
# memory usage: 156.4+ KB

# %%
df.isna().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status     50
# Age                   50
# Marital_Status        50
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose          50
# Property_Area         50
# Education_Level       50
# Gender                50
# Employer_Category     50
# Loan_Approved         50
# dtype: int64

# %% [markdown]
# ## Handel Missing Values

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns
numerical_cols = df.select_dtypes(include=["number"]).columns

# %%
categorical_cols
# Out:
# Index(['Employment_Status', 'Marital_Status', 'Loan_Purpose', 'Property_Area',
#        'Education_Level', 'Gender', 'Employer_Category', 'Loan_Approved'],
#       dtype='object')

# %%
numerical_val
# Out:
# Index(['Applicant_ID', 'Applicant_Income', 'Coapplicant_Income', 'Age',
#        'Dependents', 'Credit_Score', 'Existing_Loans', 'DTI_Ratio', 'Savings',
#        'Collateral_Value', 'Loan_Amount', 'Loan_Term'],
#       dtype='object')

# %% [markdown]
# ### using Sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer

num_imp = SimpleImputer(strategy="mean")
df[numerical_cols] = num_imp.fit_transform(df[numerical_cols])
# Out:
# C:\Users\sumit_mali\AppData\Local\Temp\ipykernel_17352\802172452.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numerical_cols] = num_imp.fit_transform(df[numerical_cols])

# %%
cat_imp = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imp.fit_transform(df[categorical_cols])
# Out:
# C:\Users\sumit_mali\AppData\Local\Temp\ipykernel_17352\3125270929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical_cols] = cat_imp.fit_transform(df[categorical_cols])

# %%
df.head()
df.isnull().sum()
# Out:
# Applicant_ID          0
# Applicant_Income      0
# Coapplicant_Income    0
# Employment_Status     0
# Age                   0
# Marital_Status        0
# Dependents            0
# Credit_Score          0
# Existing_Loans        0
# DTI_Ratio             0
# Savings               0
# Collateral_Value      0
# Loan_Amount           0
# Loan_Term             0
# Loan_Purpose          0
# Property_Area         0
# Education_Level       0
# Gender                0
# Employer_Category     0
# Loan_Approved         0
# dtype: int64

# %%
df.head()
# Out:
#     Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0            1.0           17795.0              1387.0          Salaried
# 3            4.0           13964.0              8173.0          Salaried
# 5            6.0            8265.0              4831.0          Salaried
# 6            7.0           18850.0              2768.0          Salaried
# 10          11.0           18023.0              4033.0          Salaried
#
#      Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0   51.0        Married         0.0         637.0             4.0       0.53
# 3   40.0        Married         2.0         579.0             3.0       0.31
# 5   53.0         Single         1.0         602.0             1.0       0.56
# 6   58.0        Married         0.0         687.0             0.0       0.48
# 10  52.0        Married         2.0         688.0             1.0       0.13
#
#     Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0   19403.0           45638.0      16619.0       84.0     Personal
# 3    9553.0           10844.0      27819.0       60.0     Business
# 5   19522.0            2911.0       9798.0       36.0         Home
# 6   14635.0            8991.0      26143.0       24.0         Home
# 10  18244.0           40004.0      10415.0       12.0    Education
#
#    Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0          Urban    Not Graduate  Female           Private            No
# 3          Rural        Graduate  Female        Government            No
# 5      Semiurban        Graduate    Male        Unemployed            No
# 6          Rural        Graduate    Male           Private            No
# 10         Urban    Not Graduate  Female               MNC           Yes

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le = LabelEncoder()
df["Education_Level"] = le.fit_transform(df["Education_Level"])
df["Loan_Approved"] = le.fit_transform(df["Loan_Approved"])
# Out:
# C:\Users\sumit_mali\AppData\Local\Temp\ipykernel_17352\1834957239.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Education_Level"] = le.fit_transform(df["Education_Level"])
# C:\Users\sumit_mali\AppData\Local\Temp\ipykernel_17352\1834957239.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Loan_Approved"] = le.fit_transform(df["Loan_Approved"])
